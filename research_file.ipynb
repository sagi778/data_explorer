# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

df = pd.read_csv('C:/Users/sagic/[5] Net_Worth/data/Net_Worth.csv')
df.tail()
# Out:
#           date  outcome   salery      bank  foreign_currency     trading  \
# 37  01/12/2023      NaN  31790.0   77077.0             96.35   61089.570
# 38  01/01/2024      NaN      NaN       NaN               NaN         NaN
# 39  01/02/2024      NaN  52082.0  107383.0             98.22   63860.140
# 40  01/03/2024      NaN      NaN       NaN               NaN         NaN
# 41  01/04/2024      NaN      NaN   53445.0           1490.83  188341.131
#
#     study_fund_sagi  bank_saving  rsu_mobileye  espp_intel  ...  fund_efrat1  \
# 37         145228.0     36342.91     191668.56      4328.0  ...          NaN
# 38              NaN          NaN           NaN      4328.0  ...          NaN
# 39         148024.0     36342.91      42347.26      4328.0  ...     104264.0
# 40              NaN          NaN           NaN         NaN  ...          NaN
# 41         157689.0     36342.91      45052.81      4328.0  ...     113181.0
#
# ...

# %%
column_name = 'sum'
figure, ax = plt.subplots(figsize=(6, 6))
sns.histplot(data=df, x=column_name, ax=ax)
# Out:
# <Axes: xlabel='sum', ylabel='Count'>

# %%
df[['salery']].describe().T
# Out:
#         count          mean           std  min      25%       50%       75%  \
# salery   33.0  25718.616667  11538.177277  0.0  23298.0  28006.46  31287.85
#
#              max
# salery  53060.81

# %%
df.set_index('date', inplace=True)
df.index[0:5]
# Out:
# Index(['01/11/2020', '01/12/2020', '01/01/2021', '01/02/2021', '01/03/2021'], dtype='object', name='date')

# %%
i = df.index[2]
df.loc[i,'bank']
# Out:
# 161971.98

# %%
df.columns.tolist()
# Out:
# ['date',
#  'outcome',
#  'salery',
#  'bank',
#  'foreign_currency',
#  'trading',
#  'study_fund_sagi',
#  'bank_saving',
#  'rsu_mobileye',
#  'espp_intel',
#  'espp_amat',
#  'fund_sagi',
#  'fund_efrat1',
#  'fund_efrat2',
#  'fund_ehudi',
#  'study_fund_efrat',
#  'bank_efrat',
#  'inTransfer',
#  'real_estate',
#  'mortgage',
#  'loan',
#  'sum']

# %%
df.describe().T
# Out:
#                   count          mean            std         min        25%  \
# outcome             0.0           NaN            NaN         NaN        NaN
# salery             33.0  2.571862e+04   11538.177277        0.00   23298.00
# bank               33.0  8.736879e+04   82246.879685    24483.16   34740.00
# foreign_currency   33.0  1.645298e+04   24534.231614      -17.08      25.42
# trading            33.0  2.752510e+04   19659.496034        0.00    5149.13
# study_fund_sagi    33.0  1.054028e+05   16907.164331    71528.00   97356.00
# bank_saving        33.0  1.028006e+04   14900.488926        0.00       0.00
# rsu_mobileye       33.0  9.485737e+03   22914.060953        0.00       0.00
# espp_intel         33.0  1.600668e+04   18893.651050     3984.83    4328.00
# espp_amat          33.0  1.540251e+04   11647.316309        0.00       0.00
# fund_sagi          33.0  1.288895e+05   70948.105806    34822.00   93658.00
# ...

# %%
print(df.index.name)
# Out:
# date

# %%
df.set_index('date', inplace=True)

# %%
df[['salery']]
# Out:
#               salery
# date
# 01/11/2020  26596.53
# 01/12/2020  28006.46
# 01/01/2021  21592.28
# 01/02/2021  24668.20
# 01/03/2021  53060.81
# 01/04/2021  22567.39
# 01/05/2021  11817.28
# 01/06/2021      0.00
# 01/07/2021   9166.11
# 01/08/2021      0.00
# 01/09/2021  14873.41
# 01/10/2021  24431.00
# 01/11/2021  25553.00
# 01/12/2021  29486.00
# 01/01/2022  29487.49
# 01/02/2022  31108.16
# 01/03/2022  23298.00
# 01/04/2022  23299.17
# 01/05/2022  23997.00
# 01/06/2022  28267.22
# 01/07/2022  46559.32
# 01/08/2022   2837.00
# 01/09/2022  30171.00
# 01/10/2022  26681.00
# 01/11/2022  29437.65
# 01/12/2022  30397.00
# 01/01/2023  31287.85
# 01/02/2023  42289.90
# 01/03/2023  31758.00
# 01/04/2023  31667.00
# 01/05/2023  31425.00
# 01/06/2023  31454.00
# 01/07/2023  31474.12

# %%
df.index[0]
# Out:
# '01/11/2020'

# %%
print(type(df.loc['01/11/2020','salery']))
# Out:
# <class 'numpy.float64'>

# %%
type(df.loc[0,'salery'])
# Out:
# numpy.float64

# %%
desc = df.describe()
pd.DataFrame(desc['salery'])
# Out:
#              salery
# count     33.000000
# mean   25718.616667
# std    11538.177277
# min        0.000000
# 25%    23298.000000
# 50%    28006.460000
# 75%    31287.850000
# max    53060.810000

# %%
def pow(x):
    return x*x

df.groupby(by='rsu_mobileye')['trading','salery'].agg({lambda x: np.std(x)
                                                       })
# Out:
# C:\Users\sagic\AppData\Local\Temp\ipykernel_17296\3873104913.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by='rsu_mobileye')['trading','salery'].agg({lambda x: np.std(x)
#                   trading        salery
#                  <lambda>      <lambda>
# rsu_mobileye
# 0.00          17409.64735  12040.533065
# 57759.16          0.00000      0.000000
# 59201.16       1075.91500     14.500000
# 63003.98          0.00000      0.000000
# 73863.87          0.00000      0.000000

# %%
pd.pivot_table(index='salery',columns='foreign_currency',values='sum',data=df)
# Out:
# foreign_currency   -17.08       0.00       0.49        24.78      24.87     \
# salery
# 0.00                     NaN         NaN        NaN         NaN        NaN
# 2837.00                  NaN         NaN        NaN         NaN        NaN
# 9166.11                  NaN         NaN        NaN         NaN        NaN
# 11817.28                 NaN         NaN        NaN         NaN        NaN
# 14873.41                 NaN         NaN        NaN         NaN        NaN
# 21592.28                 NaN         NaN        NaN         NaN        NaN
# 22567.39                 NaN         NaN        NaN         NaN        NaN
# 23298.00                 NaN         NaN        NaN         NaN        NaN
# 23299.17                 NaN         NaN        NaN         NaN        NaN
# 23997.00                 NaN         NaN        NaN         NaN        NaN
# 24431.00                 NaN         NaN        NaN         NaN        NaN
# ...
